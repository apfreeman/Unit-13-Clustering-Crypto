# %% [markdown]
# # Clustering Crypto

# %%
# Install the altair library for plotting
# !pip install -U altair
# Out:
# Collecting altair
#   Downloading altair-4.1.0-py3-none-any.whl (727 kB)
#      |████████████████████████████████| 727 kB 8.4 MB/s
# Requirement already satisfied: entrypoints in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (0.3)
# Requirement already satisfied: jsonschema in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (3.2.0)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (2.11.3)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (1.19.5)
# Requirement already satisfied: toolz in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (0.11.1)
# Requirement already satisfied: pandas>=0.18 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from altair) (1.1.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas>=0.18->altair) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas>=0.18->altair) (2021.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jinja2->altair) (1.1.1)
# Requirement already satisfied: importlib-metadata in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema->altair) (3.7.0)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema->altair) (49.6.0.post20210108)
# Requirement already satisfied: attrs>=17.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema->altair) (20.3.0)
# Requirement already satisfied: six>=1.11.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema->altair) (1.15.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jsonschema->altair) (0.17.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata->jsonschema->altair) (4.0.1)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata->jsonschema->altair) (3.4.0)
# Installing collected packages: altair
# Successfully installed altair-4.1.0

# %%
# Initial imports
import requests
import pandas as pd
import numpy as np
import altair as alt
from pathlib import Path
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# %% [markdown]
# ### Set Date Frame options for consistent formatting

# %%
# Set Options for dataframes
pd.set_option('display.float_format', lambda x: '%.5f' % x)
pd.set_option('display.max_rows', 1000)

# %% [markdown]
# ### Fetching Cryptocurrency Data

# %%
# Use the following endpoint to fetch json data
url = "https://min-api.cryptocompare.com/data/all/coinlist"

# %%
# Create a DataFrame 
# Get crypto data using call to CryptoCompare API endpoint
crypto_response_data = requests.get(url)

# Convert response from api call to json format
crypto_response_data_json = crypto_response_data.json()

# Reach into json response content and select the Data then Create DataFrame 
crypto_data = pd.DataFrame(crypto_response_data_json["Data"])

# Transponse Date Frame and inspect
crypto_df = crypto_data.T
crypto_df.head()
# Out:
#          Id                  Url                         ImageUrl  \
# 42     4321   /coins/42/overview           /media/35650717/42.jpg
# 300  749869  /coins/300/overview          /media/27010595/300.png
# 365   33639  /coins/365/overview            /media/352070/365.png
# 404   21227  /coins/404/overview  /media/35650851/404-300x300.jpg
# 433  926547  /coins/433/overview          /media/34836095/433.png
#
#     ContentCreatedOn Name Symbol   CoinName         FullName  \
# 42        1427211129   42     42    42 Coin     42 Coin (42)
# 300       1517935016  300    300  300 token  300 token (300)
# 365       1480032918  365    365    365Coin    365Coin (365)
# 404       1466100361  404    404    404Coin    404Coin (404)
# 433       1541597321  433    433  433 Token  433 Token (433)
#
#                                            Description AssetTokenStatus  ...  \
# 42   Everything about 42 coin is 42 - apart from th...              N/A  ...
# 300  300 token is an ERC20 token. This Token was cr...              N/A  ...
# 365  365Coin is a Proof of Work and Proof of Stake ...              N/A  ...
# 404  404 is a PoW/PoS hybrid cryptocurrency that al...              N/A  ...
# 433  433 Token is a decentralised soccer platform t...         Finished  ...
#
#     MaxSupply MktCapPenalty IsUsedInDefi IsUsedInNft PlatformType  \
# 42         42             0            0           0   blockchain
# 300       300             0            0           0        token
# 365        -1             0            0           0   blockchain
# 404        -1             0            0           0   blockchain
# 433       NaN           NaN          NaN         NaN          NaN
#
#     AlgorithmType Difficulty BuiltOn  \
# 42         scrypt    3.10799     NaN
# 300           NaN        NaN     ETH
# 365           NaN        NaN     NaN
# 404           NaN        NaN     NaN
# 433           NaN        NaN     NaN
#
#                            SmartContractAddress DecimalPoints
# 42                                          NaN           NaN
# 300  0xaec98a708810414878c3bcdf46aad31ded4a4557            18
# 365                                         NaN           NaN
# 404                                         NaN           NaN
# 433                                         NaN           NaN
#
# [5 rows x 36 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
# Keep only necessary columns:
# 'CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','CirculatingSupply'
crypto_df = crypto_df.filter(['CoinName','Algorithm','IsTrading','ProofType','TotalCoinsMined','MaxSupply'])
crypto_df.head()
# Out:
#       CoinName Algorithm IsTrading ProofType TotalCoinsMined MaxSupply
# 42     42 Coin    Scrypt      True   PoW/PoS        41.99995        42
# 300  300 token       N/A      True       N/A             300       300
# 365    365Coin       X11      True   PoW/PoS               0        -1
# 404    404Coin    Scrypt      True   PoW/PoS               0        -1
# 433  433 Token       N/A     False       N/A             NaN       NaN

# %%
# Keep only cryptocurrencies that are trading
crypto_df = crypto_df.loc[crypto_df['IsTrading'] == True]

# %%
# Keep only cryptocurrencies with a working algorithm
crypto_df = crypto_df.loc[crypto_df['Algorithm'] != 'N/A']

# %%
# Remove the "IsTrading" column
crypto_df.drop(columns = 'IsTrading', inplace=True)

# %%
# Count Null Values in dataframe
crypto_df.isnull().sum()
# Out:
# CoinName             0
# Algorithm            0
# ProofType            0
# TotalCoinsMined    949
# MaxSupply          949
# dtype: int64

# %%
# Remove rows with at least 1 null value
crypto_df.dropna(inplace = True)

# Check Null count post dropna
crypto_df.isnull().sum()
# Out:
# CoinName           0
# Algorithm          0
# ProofType          0
# TotalCoinsMined    0
# MaxSupply          0
# dtype: int64

# %%
# Remove rows with cryptocurrencies having no coins mined
crypto_df = crypto_df.loc[crypto_df['TotalCoinsMined'] > 0]

# %%
# Find the Columns where there are any N/A Text Values
crypto_df.columns[crypto_df.isin(['N/A']).any()]
# Out:
# Index(['ProofType'], dtype='object')

# %%
# Drop rows where there are 'N/A' text values
# The above code identified only the ProofType column contains N/A text values
crypto_df = crypto_df.loc[crypto_df['ProofType'] != 'N/A']

# %%
# Store the 'CoinName'column in its own DataFrame prior to dropping it from crypto_df
crypto_coin_name = pd.DataFrame(crypto_df['CoinName'])
crypto_coin_name.head(3)
# Out:
#            CoinName
# 42          42 Coin
# NSR        NuShares
# TRI  Triangles Coin

# %%
# Drop the 'CoinName' column since it's not going to be used on the clustering algorithm
crypto_df.drop(columns="CoinName", inplace=True)
crypto_df.head()
# Out:
#      Algorithm ProofType  TotalCoinsMined MaxSupply
# 42      Scrypt   PoW/PoS         41.99995        42
# NSR        PoS       PoS 6172691537.83110         0
# TRI        X13   PoW/PoS     191620.84240         0
# CMTC    Scrypt       PoW           872830         0
# CHAT    Scrypt   PoW/PoS       1000000000        -1

# %%
# Check Data Types for Data Frame to see which need to be converted to numeric with get_dummies
crypto_df.select_dtypes(include='object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133 entries, 42 to SIGNA
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Algorithm        133 non-null    object
#  1   ProofType        133 non-null    object
#  2   TotalCoinsMined  133 non-null    object
#  3   MaxSupply        133 non-null    object
# dtypes: object(4)
# memory usage: 5.2+ KB

# %%
# Convert TotalCoinSupply and MaxSupply column to float data type
crypto_df = crypto_df.astype({"TotalCoinsMined": float, "MaxSupply": float})

# %%
# Create dummy variables for the remaining text features
X = pd.get_dummies(crypto_df, columns=['Algorithm', 'ProofType'])

# %%
# Standardize data
X_scaled = StandardScaler().fit_transform(X)
print(X_scaled[0:5])
# Out:
# [[-0.09938151 -0.0932114  -0.08703883 -0.08703883 -0.08703883 -0.12356041
#   -0.08703883 -0.08703883 -0.12356041 -0.12356041 -0.15191091 -0.08703883
#   -0.08703883 -0.08703883 -0.23570226 -0.12356041 -0.08703883 -0.08703883
#   -0.08703883 -0.3002731  -0.08703883 -0.08703883 -0.23570226 -0.08703883
#   -0.08703883 -0.12356041 -0.08703883 -0.08703883 -0.08703883 -0.08703883
#   -0.08703883 -0.08703883 -0.15191091 -0.08703883 -0.08703883 -0.12356041
#   -0.19764235 -0.08703883 -0.08703883 -0.12356041 -0.12356041 -0.3002731
#   -0.12356041 -0.08703883 -0.08703883 -0.08703883  2.18691762 -0.08703883
#   -0.08703883 -0.08703883 -0.08703883 -0.17609018 -0.08703883 -0.19764235
#   -0.12356041 -0.08703883 -0.08703883 -0.08703883 -0.08703883 -0.08703883
#   -0.25298221 -0.08703883 -0.08703883 -0.12356041 -0.12356041 -0.08703883
#   -0.31491833 -0.08703883 -0.08703883 -0.08703883 -0.96308682  2.07846097
#   -0.08703883 -0.08703883 -0.08703883 -0.08703883 -0.08703883 -0.08703883
#   -0.08703883 -0.08703883 -0.08703883 -0.08703883]
#  [-0.09562299 -0.0932114  -0.08703883 -0.08703883 -0.08703883 -0.12356041
#   -0.08703883 -0.08703883 -0.12356041 -0.12356041 -0.15191091 -0.08703883
#   -0.08703883 -0.08703883 -0.23570226 -0.12356041 -0.08703883 -0.08703883
#   -0.08703883 -0.3002731  -0.08703883 -0.08703883 -0.23570226 -0.08703883
#   -0.08703883 -0.12356041 -0.08703883 -0.08703883 -0.08703883 -0.08703883
#   -0.08703883 -0.08703883 -0.15191091 -0.08703883 -0.08703883 -0.12356041
#    5.05964426 -0.08703883 -0.08703883 -0.12356041 -0.12356041 -0.3002731
#   -0.12356041 -0.08703883 -0.08703883 -0.08703883 -0.45726459 -0.08703883
#   -0.08703883 -0.08703883 -0.08703883 -0.17609018 -0.08703883 -0.19764235
#   -0.12356041 -0.08703883 -0.08703883 -0.08703883 -0.08703883 -0.08703883
#   -0.25298221 -0.08703883 -0.08703883 -0.12356041 -0.12356041 -0.08703883
#    3.17542648 -0.08703883 -0.08703883 -0.08703883 -0.96308682 -0.48112522
#   -0.08703883 -0.08703883 -0.08703883 -0.08703883 -0.08703883 -0.08703883
#   -0.08703883 -0.08703883 -0.08703883 -0.08703883]
#  [-0.0993814  -0.0932114  -0.08703883 -0.08703883 -0.08703883 -0.12356041
#   -0.08703883 -0.08703883 -0.12356041 -0.12356041 -0.15191091 -0.08703883
#   -0.08703883 -0.08703883 -0.23570226 -0.12356041 -0.08703883 -0.08703883
#   -0.08703883 -0.3002731  -0.08703883 -0.08703883 -0.23570226 -0.08703883
#   -0.08703883 -0.12356041 -0.08703883 -0.08703883 -0.08703883 -0.08703883
#   -0.08703883 -0.08703883 -0.15191091 -0.08703883 -0.08703883 -0.12356041
#   -0.19764235 -0.08703883 -0.08703883 -0.12356041 -0.12356041 -0.3002731
#   -0.12356041 -0.08703883 -0.08703883 -0.08703883 -0.45726459 -0.08703883
#   -0.08703883 -0.08703883 -0.08703883 -0.17609018 -0.08703883  5.05964426
#   -0.12356041 -0.08703883 -0.08703883 -0.08703883 -0.08703883 -0.08703883
#   -0.25298221 -0.08703883 -0.08703883 -0.12356041 -0.12356041 -0.08703883
#   -0.31491833 -0.08703883 -0.08703883 -0.08703883 -0.96308682  2.07846097
#   -0.08703883 -0.08703883 -0.08703883 -0.08703883 -0.08703883 -0.08703883
#   -0.08703883 -0.08703883 -0.08703883 -0.08703883]
#  [-0.09938098 -0.0932114  -0.08703883 -0.08703883 -0.08703883 -0.12356041
#   -0.08703883 -0.08703883 -0.12356041 -0.12356041 -0.15191091 -0.08703883
#   -0.08703883 -0.08703883 -0.23570226 -0.12356041 -0.08703883 -0.08703883
#   -0.08703883 -0.3002731  -0.08703883 -0.08703883 -0.23570226 -0.08703883
#   -0.08703883 -0.12356041 -0.08703883 -0.08703883 -0.08703883 -0.08703883
#   -0.08703883 -0.08703883 -0.15191091 -0.08703883 -0.08703883 -0.12356041
#   -0.19764235 -0.08703883 -0.08703883 -0.12356041 -0.12356041 -0.3002731
#   -0.12356041 -0.08703883 -0.08703883 -0.08703883  2.18691762 -0.08703883
#   -0.08703883 -0.08703883 -0.08703883 -0.17609018 -0.08703883 -0.19764235
#   -0.12356041 -0.08703883 -0.08703883 -0.08703883 -0.08703883 -0.08703883
#   -0.25298221 -0.08703883 -0.08703883 -0.12356041 -0.12356041 -0.08703883
#   -0.31491833 -0.08703883 -0.08703883 -0.08703883  1.03832798 -0.48112522
#   -0.08703883 -0.08703883 -0.08703883 -0.08703883 -0.08703883 -0.08703883
#   -0.08703883 -0.08703883 -0.08703883 -0.08703883]
#  [-0.09877262 -0.0932114  -0.08703883 -0.08703883 -0.08703883 -0.12356041
#   -0.08703883 -0.08703883 -0.12356041 -0.12356041 -0.15191091 -0.08703883
#   -0.08703883 -0.08703883 -0.23570226 -0.12356041 -0.08703883 -0.08703883
#   -0.08703883 -0.3002731  -0.08703883 -0.08703883 -0.23570226 -0.08703883
#   -0.08703883 -0.12356041 -0.08703883 -0.08703883 -0.08703883 -0.08703883
#   -0.08703883 -0.08703883 -0.15191091 -0.08703883 -0.08703883 -0.12356041
#   -0.19764235 -0.08703883 -0.08703883 -0.12356041 -0.12356041 -0.3002731
#   -0.12356041 -0.08703883 -0.08703883 -0.08703883  2.18691762 -0.08703883
#   -0.08703883 -0.08703883 -0.08703883 -0.17609018 -0.08703883 -0.19764235
#   -0.12356041 -0.08703883 -0.08703883 -0.08703883 -0.08703883 -0.08703883
#   -0.25298221 -0.08703883 -0.08703883 -0.12356041 -0.12356041 -0.08703883
#   -0.31491833 -0.08703883 -0.08703883 -0.08703883 -0.96308682  2.07846097
#   -0.08703883 -0.08703883 -0.08703883 -0.08703883 -0.08703883 -0.08703883
#   -0.08703883 -0.08703883 -0.08703883 -0.08703883]]

# %% [markdown]
# ### Data has been cleaned and scaled and is ready for PCA and Clustering

# %% [markdown]
# ### Reducing Dimensions Using PCA

# %%
# Use PCA to reduce dimensions to 3 principal components
pca = PCA(n_components=3)
crypto_pca = pca.fit_transform(X_scaled)

# %%
# Create a DataFrame with the principal components data
pcs_df = pd.DataFrame(
    data=crypto_pca, columns=["PC 1", "PC 2", "PC 3"], index=crypto_df.index
)
pcs_df.head(10)
# Out:
#          PC 1     PC 2     PC 3
# 42   -0.90470 -0.98218 -0.28106
# NSR  -1.28520  0.57579 -0.64769
# TRI  -1.48123 -0.80279 -0.30291
# CMTC  0.68832 -0.82446 -0.23626
# CHAT -0.90447 -0.98196 -0.28101
# QRL   1.26054 -0.64431 -0.15855
# PURA  0.47980 -0.64375 -0.12856
# BTCP  1.07035 -0.69789 -0.16525
# ADK   0.85857 -0.55982 -0.10366
# DAPS -1.52323  1.40868  6.71409

# %% [markdown]
# ### Clustering Crytocurrencies Using K-Means
#
# #### Find the Best Value for `k` Using the Elbow Curve

# %%
inertia = []
k = list(range(1, 11))

# Calculate the inertia for the range of k values
for i in k:
    km = KMeans(n_clusters=i, random_state=0)
    km.fit(pcs_df)
    inertia.append(km.inertia_)

# Create the DateFrame for plotting
elbow_data = {"k": k, "inertia": inertia}
df_elbow = pd.DataFrame(elbow_data)

# Plot the Elbow Curve using Altair Scatter Plot
alt.Chart(df_elbow).mark_circle(size=60).encode(
    x="k", 
    y="inertia", 
    color=alt.Color('inertia', scale=alt.Scale(scheme='viridis')),
    tooltip=['inertia', 'k']
)
# Out:
# alt.Chart(...)

# %% [markdown]
# Running K-Means with `k=5`

# %%
# Initialize the K-Means model
model = KMeans(n_clusters=5, random_state=0)

# Fit the model
model.fit(pcs_df)

# Predict clusters
predictions = model.predict(pcs_df)

# Create a new DataFrame including predicted clusters and cryptocurrencies features
clustered_df = pd.DataFrame({
    "Algorithm": crypto_df.Algorithm,
    "ProofType": crypto_df.ProofType,
    "TotalCoinsMined": crypto_df.TotalCoinsMined,
    "MaxSupply": crypto_df.MaxSupply,
    "PC 1": pcs_df['PC 1'],
    "PC 2": pcs_df['PC 2'],
    "PC 3": pcs_df['PC 3'],
    "CoinName": crypto_coin_name.CoinName,
    "Class": model.labels_,
    },
    index=crypto_df.index
)
clustered_df.head()
# Out:
#      Algorithm ProofType  TotalCoinsMined  MaxSupply     PC 1     PC 2  \
# 42      Scrypt   PoW/PoS         41.99995   42.00000 -0.90470 -0.98218
# NSR        PoS       PoS 6172691537.83110    0.00000 -1.28520  0.57579
# TRI        X13   PoW/PoS     191620.84240    0.00000 -1.48123 -0.80279
# CMTC    Scrypt       PoW     872830.00000    0.00000  0.68832 -0.82446
# CHAT    Scrypt   PoW/PoS 1000000000.00000   -1.00000 -0.90447 -0.98196
#
#          PC 3        CoinName  Class
# 42   -0.28106         42 Coin      1
# NSR  -0.64769        NuShares      1
# TRI  -0.30291  Triangles Coin      1
# CMTC -0.23626       CometCoin      0
# CHAT -0.28101        OpenChat      1

# %% [markdown]
# ### Visualizing Results

# %% [markdown]
# #### Scatter Plot with Tradable Cryptocurrencies

# %%
# Scale data to create the scatter plot
clustered_scaled_df = pd.DataFrame(StandardScaler().fit_transform(clustered_df[["TotalCoinsMined", "MaxSupply"]]), index=clustered_df.index)
clustered_scaled_df.head()
# Out:
#             0        1
# 42   -0.09938 -0.09321
# NSR  -0.09562 -0.09321
# TRI  -0.09938 -0.09321
# CMTC -0.09938 -0.09321
# CHAT -0.09877 -0.09321

# %%
# Create a new DataFrame including predicted clusters and cryptocurrencies features
df = pd.DataFrame({
    "Algorithm": clustered_df.Algorithm,
    "ProofType": clustered_df.ProofType,
    "TotalCoinsMined": clustered_scaled_df[0],
    "MaxSupply": clustered_scaled_df[1],
    "PC 1": clustered_df['PC 1'],
    "PC 2": clustered_df['PC 2'],
    "PC 3": clustered_df['PC 3'],
    "CoinName": clustered_df.CoinName,
    "Class": clustered_df.Class,
    },
    index=crypto_df.index
)
df.head()
# Out:
#      Algorithm ProofType  TotalCoinsMined  MaxSupply     PC 1     PC 2  \
# 42      Scrypt   PoW/PoS         -0.09938   -0.09321 -0.90470 -0.98218
# NSR        PoS       PoS         -0.09562   -0.09321 -1.28520  0.57579
# TRI        X13   PoW/PoS         -0.09938   -0.09321 -1.48123 -0.80279
# CMTC    Scrypt       PoW         -0.09938   -0.09321  0.68832 -0.82446
# CHAT    Scrypt   PoW/PoS         -0.09877   -0.09321 -0.90447 -0.98196
#
#          PC 3        CoinName  Class
# 42   -0.28106         42 Coin      1
# NSR  -0.64769        NuShares      1
# TRI  -0.30291  Triangles Coin      1
# CMTC -0.23626       CometCoin      0
# CHAT -0.28101        OpenChat      1

# %%
# Use the altair scatter plot to visualize the clusters, x="PC 1" and y="PC 2" for the axes
alt.Chart(df).mark_circle(size=60).encode(
    x="PC 1", 
    y="PC 2", 
    color=alt.Color('Class', scale=alt.Scale(scheme='viridis')),
    # Add the required tool tips "CoinName", "Algorithm", "TotalCoinsMined", "TotalCoinSupply"
    tooltip=["CoinName", "Algorithm", "TotalCoinsMined", "MaxSupply"]
)
# Out:
# alt.Chart(...)

# %%
#Use the altair scatter plot to visualize the tradable cryptocurrencies, x="TotalCoinsMined" and y="TotalCoinSupply" for the axes
alt.Chart(df).mark_circle(size=60).encode(
    x="TotalCoinsMined",
    y="MaxSupply",
    color=alt.Color('Class', scale=alt.Scale(scheme='viridis')),
    # Add the required tool tips "CoinName", "Algorithm", "TotalCoinsMined", "TotalCoinSupply"
    tooltip=["CoinName", "Algorithm", "TotalCoinsMined", "MaxSupply"]
)
# Out:
# alt.Chart(...)

# %% [markdown]
# #### Table of Tradable Cryptocurrencies

# %%
# Order DF alphabetically 
clustered_df = clustered_df.sort_values("CoinName")

# Print the total number of tradable cryptocurrencies using the display() command
display(clustered_df[['CoinName','Algorithm', 'ProofType', 'MaxSupply', 'TotalCoinsMined', 'Class']])
# Out:
#                                      CoinName              Algorithm  \
# 42                                    42 Coin                 Scrypt
# AEON                                     AEON       CryptoNight-Lite
# ARK                                       ARK                   DPoS
# ACT                                    Achain                   DPoS
# AAC                         Acute Angle Cloud              ECC 256K1
# ADK                              Aidos Kuneen                  IMesh
# AION                                     Aion          Equihash210,9
# AMB                                     Amber                 Dagger
# ANC                           Anchor Protocol                    PoS
# AR                                    Arweave                SHA-256
# AURORAC                            Auroracoin                 Scrypt
# BLOCM                              BLOC.MONEY      Cryptonight Haven
# BEAM                                     Beam               Equihash
# BCMC1                     BeforeCoinMarketCap                 Ethash
# BDX                                    Beldex            CryptoNight
# BNB                              Binance Coin                  BEP-2
# BTT                                BitTorrent                 TRC-10
# BTC                                   Bitcoin                SHA-256
# BCH                              Bitcoin Cash                SHA-256
# BCD                           Bitcoin Diamond                    X13
# BTG                              Bitcoin Gold               Equihash
# BTCP                          Bitcoin Private               Equihash
# BSV                                Bitcoin SV                SHA-256
# BTCZ                                 BitcoinZ               Equihash
# BTH                                 Bithereum               Equihash
# BTS                                 Bitshares                SHA-512
# BLK                                 BlackCoin                 Scrypt
# BCN                                  ByteCoin            CryptoNight
# CLO                          Callisto Network                 Ethash
# CDN                              Canada eCoin                 Scrypt
# ADA                                   Cardano              Ouroboros
# COVAL                       Circuits of Value               Multiple
# CLOAK                               CloakCoin                    X13
# CMTC                                CometCoin                 Scrypt
# DAPS                                DAPS Coin                 Dagger
# DASH                                     Dash                    X11
# DCR                                    Decred               BLAKE256
# DERO                                     Dero            CryptoNight
# DGB                                  DigiByte               Multiple
# XDN                               DigitalNote       BMW512 / Echo512
# DOGE                                 Dogecoin                 Scrypt
# EOS                                       EOS                   DPoS
# EMC2                              Einsteinium                 Scrypt
# EMC                                  Emercoin                SHA-256
# ERG                                      Ergo              Autolykos
# ETZ                                 EtherZero                 Ethash
# ETH                                  Ethereum                 Ethash
# ETC                          Ethereum Classic                EtcHash
# ENS                     Ethereum Name Service                 Ethash
# EXP                                   Expanse                 Ethash
# FTC                               FeatherCoin              NeoScrypt
# FIRO                                     Firo                    MTP
# FLO                                       Flo                 Scrypt
# GENIX                                   Genix                   X16R
# GMX                               Goldmaxcoin                 Scrypt
# GRIN                                     Grin                    C31
# GRS                               Groestlcoin                Groestl
# NLG                                    Gulden                 Scrypt
# HNS                                 Handshake         Blake2B + SHA3
# XHV                            Haven Protocol      CryptoNight-Heavy
# ZEN                                   Horizen               Equihash
# HC                                  HyperCash               BLAKE256
# ICX                              ICON Project              Loopchain
# IOC                                    IOCoin                    X11
# INT                       Internet Node token                  IMesh
# KCASH                                   Kcash                SHA-512
# KMD                                    Komodo               Equihash
# LSK                                      Lisk                   DPoS
# LTC                                  Litecoin                 Scrypt
# MAPS                                     MAPS              SPL Token
# MEC                                  MegaCoin                 Scrypt
# MWC                          MimbleWimbleCoin                    C31
# MONA                                 MonaCoin                 Scrypt
# XMR                                    Monero                RandomX
# NMC                                  Namecoin                SHA-256
# NANO                                     Nano                Blake2b
# NAV                                   NavCoin                    X13
# CKB                            Nervos Network              Eaglesong
# NXS                                     Nexus                   SHA3
# NVC                                  NovaCoin                 Scrypt
# NSR                                  NuShares                    PoS
# NXT                                       Nxt                    PoS
# ONT                                  Ontology                   VBFT
# CHAT                                 OpenChat                 Scrypt
# OXYC                                  Oxycoin                   DPoS
# ARRR                             Pirate Chain               Equihash
# POA                               Poa Network     Proof-of-Authority
# POT                                   PotCoin                 Scrypt
# PST                                    Primas                 Scrypt
# PIVX     Private Instant Verified Transaction                  Quark
# PURA                                     Pura                    X11
# QTUM                                     QTUM                POS 3.0
# QRL                  Quantum Resistant Ledger                RandomX
# QRK                                 QuarkCoin                  Quark
# RVC                         Ravencoin Classic                   X16R
# RDD                                  Reddcoin                 Scrypt
# RISE                                     Rise                   DPoS
# SAFEX                        SafeExchangeCoin                 Scrypt
# SFP                                   SafePal           BEP-20 Token
# SLS                                     SaluS                 Scrypt
# SHIFT                                   Shift                   DPoS
# SC                                    Siacoin                Blake2b
# SIB                                   SibCoin                X11GOST
# SIGNA                                   Signa              Shabal256
# RBTC                            Smart Bitcoin                SHA-256
# SMART                               SmartCash                 KECCAK
# XSN                                  Stakenet                    X11
# STEEM                                   Steem                    PoS
# STRAX                                 Stratis                    X13
# SERO                               Super Zero                 Ethash
# SYS                                   SysCoin                SHA-256
# TENT                                     TENT               Equihash
# TCR                                 TecraCoin                 Lyra2Z
# TPAY                                 TokenPay                POS 3.0
# TRI                            Triangles Coin                    X13
# UBQ                                      Ubiq       Dagger-Hashimoto
# UBTC                            UnitedBitcoin                SHA-256
# VSYS                                V Systems                   SPoS
# VEIL                                     VEIL                  X16RT
# VAL                                  Validity                    PoS
# VET                                   VeChain  VeChainThor Authority
# XVG                                     Verge               Multiple
# VRC                                  VeriCoin                 Scrypt
# VTC                                  Vertcoin              Lyra2REv2
# VIA                                   ViaCoin                 Scrypt
# WAVES                                   Waves             Leased POS
# XWC                                 WhiteCoin                 Scrypt
# WBBC                                  Wibcoin                SHA-256
# XDNA                                     XDNA                    HEX
# ZEC                                     ZCash               Equihash
# ZANO                                     Zano               ProgPowZ
# ZEL                                   Zelcash               Equihash
# XEC                                     eCash                SHA-256
#
#                     ProofType            MaxSupply      TotalCoinsMined  Class
# 42                    PoW/PoS             42.00000             41.99995      1
# AEON                      PoW             -1.00000       18019772.72546      0
# ARK                      DPoS             -1.00000      163233684.00000      3
# ACT                      DPoS              0.00000     1000000000.00000      3
# AAC                      DPOS             -1.00000     1000000000.00000      4
# ADK                       PoW              0.00000       25000000.00000      0
# AION                  PoW/PoS             -1.00000      501800769.00000      1
# AMB                       PoA             -1.00000      906024641.00000      4
# ANC                       PoS             -1.00000     1000000000.00000      1
# AR                        PoW       66000000.00000       64598643.00000      0
# AURORAC               PoW/PoS             -1.00000       99865603.45202      1
# BLOCM                     PoW       50000000.00000       21489362.95380      0
# BEAM                      PoW      262800000.00000       69527581.68901      0
# BCMC1                 PoW/PoS             -1.00000     8553027612.56205      1
# BDX                       PoS             -1.00000     1400222610.00000      1
# BNB                       BFT             -1.00000      165123057.09000      4
# BTT                      DPoS             -1.00000   989988441431.74915      3
# BTC                       PoW       20999999.97690       18958481.00000      0
# BCH                       PoW       20999999.97690       18983443.64665      0
# BCD                   PoW/PoS      210000000.00000      202563875.00000      1
# BTG                       PoW       21000000.00000       18971961.11089      0
# BTCP                      PoW       22873588.00000        3818878.38780      0
# BSV                       PoW       20999999.97690       18979545.39424      0
# BTCZ                      PoW    21000000000.00000    10859921140.80475      0
# BTH                       PoW              0.00000       30886000.00000      0
# BTS                      DPoS     3600570502.00000     2994634656.66322      3
# BLK                       PoS      100000000.00000       61194807.34648      1
# BCN                       PoW   184470000000.00000   184467440737.09552      0
# CLO                       PoW     6500000000.00000     3110980485.58751      0
# CDN                    AuxPoW      107364500.00000       99912375.00000      1
# ADA                       PoS    45000000000.00000    33024265421.39082      1
# COVAL                     PoW             -1.00000     1777720436.01624      0
# CLOAK                 PoW/PoS             -1.00000        5762333.55277      1
# CMTC                      PoW              0.00000         872830.00000      0
# DAPS              PoW/PoS/PoA    70000000000.00000    62319462900.00000      4
# DASH                 PoW/PoSe       18900000.00000       10584413.24327      1
# DCR                   PoW/PoS       21000000.00000       13767593.42253      1
# DERO                      PoW             -1.00000       18400000.00000      0
# DGB                       PoW    21000000000.00000    15095789994.94556      0
# XDN                   PoW/PoS             -1.00000     8077915717.57413      1
# DOGE                      PoW             -1.00000   133220906383.70525      0
# EOS                      DPoS             -1.00000     1047112868.94930      3
# EMC2                      PoW             -1.00000      222344814.50000      0
# EMC                   PoW/PoS             -1.00000       48123001.35409      0
# ERG                       PoW       97739924.50000       50610381.00000      0
# ETZ                       PoW             -1.00000      228471761.95000      0
# ETH                       PoW             -1.00000      119585354.74900      0
# ETC                       PoW      210700000.00000      131615239.05573      0
# ENS             Proof-of-Work             -1.00000      100000000.00000      1
# EXP                       PoW      100000000.00000       34700351.97000      0
# FTC                       PoW      336000000.00000      255027998.00773      0
# FIRO                      PoW       21400000.00000       12903324.65440      0
# FLO                       PoW      160000000.00000      139520931.58140      0
# GENIX                     PoW      210000000.00000      109619688.00000      0
# GMX                       PoW             -1.00000      966998041.09718      0
# GRIN                      PoW             -1.00000       84962482.63950      0
# GRS                       PoW      105000000.00000       79439803.88739      0
# NLG                       PoW     1680000000.00000      540269469.29672      0
# HNS                       PoW     2040000000.00000      466066443.83512      0
# XHV                       PoW             -1.00000       14478967.85208      0
# ZEN                       PoW       21000000.00000       12067462.50000      0
# HC                    PoW/PoS       84000000.00000       45071909.32905      1
# ICX                       PoS             -1.00000      922823371.95197      1
# IOC                   PoW/PoS       22000000.00000       19404317.97435      1
# INT                 DPoS/dBFT     1000000000.00000      763616165.72213      1
# KCASH    Zero-Knowledge Proof             -1.00000     1000000000.00000      3
# KMD                  dPoW/PoW      200000000.00000      132242229.94331      0
# LSK                      DPoS             -1.00000      144818773.00000      3
# LTC                       PoW       84000000.00000       69641895.73347      0
# MAPS                      PoH    10000000000.00000     1000000000.00000      4
# MEC                       PoW       42000000.00000       39857594.36810      0
# MWC                       PoW       20000000.00000       10817988.65694      0
# MONA                      PoW             -1.00000       84820449.97158      0
# XMR                       PoW             -1.00000       18079006.91926      0
# NMC                       PoW             -1.00000       17988025.00000      0
# NANO                      PoW      133248290.00000      133248290.00000      0
# NAV                   PoW/PoS             -1.00000       72843170.02016      1
# CKB                       PoW             -1.00000    35595911587.24194      0
# NXS                  PoW/nPoS       78000000.00000       72736807.62326      4
# NVC                   PoW/PoS             -1.00000        3584851.72444      1
# NSR                       PoS              0.00000     6172691537.83110      1
# NXT                  PoS/LPoS     1000000000.00000      998999927.93769      1
# ONT                       PoS             -1.00000     1000000000.00000      1
# CHAT                  PoW/PoS             -1.00000     1000000000.00000      1
# OXYC                     DPoS             -1.00000     1122382283.37000      3
# ARRR                     dPoW      200000000.00000      190244262.44849      0
# POA                       PoA             -1.00000      180669861.97120      4
# POT                   PoW/PoS      420000000.00000      227389863.91924      1
# PST                       PoW             -1.00000      100000000.00000      0
# PIVX                  PoW/PoS             -1.00000       68318765.26841      1
# PURA                      PoW             -1.00000      188358976.83970      0
# QTUM                      PoS      107822402.25000      104043688.00000      1
# QRL                       PoW      105000000.00000       75956291.80476      0
# QRK                   PoW/PoS             -1.00000      278096734.68129      1
# RVC                       PoW    21000000000.00000    10500390602.67635      0
# RDD                   PoW/PoS             -1.00000    30766961503.24677      1
# RISE                      PoS             -1.00000      193696723.41000      3
# SAFEX                     PoC             -1.00000     2147483647.00000      1
# SFP                      PoSA             -1.00000      500000000.00000      4
# SLS                   PoW/PoS             -1.00000        1033953.85742      1
# SHIFT                    DPoS             -1.00000       14838303.00000      3
# SC                        PoW             -1.00000    50167972992.00000      0
# SIB                       PoW       21000000.00000       19702149.48524      0
# SIGNA                     PoC             -1.00000     2139128600.00000      1
# RBTC                      PoW       21000000.00000           2426.52033      0
# SMART                     PoW     5000000000.00000     2729971974.23311      0
# XSN                      TPoS             -1.00000      127870221.40831      1
# STEEM                     PoW             -1.00000      387171561.89800      0
# STRAX                     PoS             -1.00000      133887555.40601      1
# SERO              ProgPoW/PoS      650000000.00000      334031560.00000      1
# SYS                       PoW      888000000.00000      633202143.97719      0
# TENT                      PoW       84096000.00000       38742200.00000      0
# TCR                       PoW             -1.00000         417412.67840      0
# TPAY                      PoS       25000000.00000       21880393.00000      1
# TRI                   PoW/PoS              0.00000         191620.84240      1
# UBQ                       PoW             -1.00000       51066418.85397      0
# UBTC                      PoW       21000000.00000       21000000.00000      0
# VSYS                     SPoS             -1.00000     6048829095.00000      4
# VEIL                  PoW/PoS      300000000.00000      119516479.71487      1
# VAL                       PoS        9000000.00000        4510056.65813      1
# VET        Proof of Authority    86712634466.00000    85985041177.00000      4
# XVG                       PoW    16555000000.00000    16496863237.83363      0
# VRC                      PoST             -1.00000       34682237.69183      1
# VTC                       PoW       84000000.00000       63490886.31663      0
# VIA                       PoW             -1.00000       23174976.58839      0
# WAVES                    LPoS             -1.00000      107495704.00000      4
# XWC                   PoW/PoS     1000000000.00000      954229595.00000      1
# WBBC                      PoW  1000016730264.43506  1000016730264.43506      0
# XDNA                  PoW/PoS              0.00000        8830765.00000      1
# ZEC                       PoW       21000000.00000       12123628.29130      0
# ZANO                  PoW/PoS             -1.00000       13065488.39987      1
# ZEL                   PoW/PoS      210000000.00000      440000000.00000      1
# XEC                       PoW 21000000000000.00000 18979527146789.37891      2
